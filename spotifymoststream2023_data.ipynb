# %% [markdown]
# <a href="https://colab.research.google.com/github/naisyahmh75/formula/blob/main/spotifymoststream2023_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

import os
os.makedirs("/content/.kaggle/", exist_ok = True)

# import kaggle json file
from google.colab import files

# !chmod 600 /content/.kaggle/kaggle.json

# %%
# download dataset using kaggle API
! kaggle datasets download -d nelgiriyewithana/top-spotify-songs-2023
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/top-spotify-songs-2023
# License(s): other
# ...
#   0% 0.00/47.1k [00:00<?, ?B/s]
# 100% 47.1k/47.1k [00:00<00:00, 51.0MB/s]

# %%
# unzip
import zipfile
import os

with zipfile.ZipFile("/content/top-spotify-songs-2023.zip", "r") as zip_ref:
  zip_ref.extractall("spotidy-data")

# list of the file extracted
os.listdir("spotidy-data")
# Out:
# ['spotify-2023.csv']

# %%
import pandas as pd
spotify_data = pd.read_csv("/content/spotidy-data/spotify-2023.csv", encoding='latin-1')
spotify_data.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
spotify_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
spotify_data.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
spotify_data[spotify_data['released_month']==7]
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 7                                             Columbia
# 11                                           Super Shy
# 17   What Was I Made For? [From The Motion Picture ...
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# ..                                                 ...
# 909                                             Static
# 911                                             Sparks
# 915                                         Sin Seï¿½ï
# 924                            2 Be Loved (Am I Ready)
# 930                                Casei Com a Putaria
#
#                          artist(s)_name  artist_count  released_year  \
# 0                      Latto, Jung Kook             2           2023
# 7                               Quevedo             1           2023
# 11                             NewJeans             1           2023
# ...

# %%
spotify_data[spotify_data['released_year']==2023]
# Out:
#                               track_name  \
# 0    Seven (feat. Latto) (Explicit Ver.)
# 1                                   LALA
# 2                                vampire
# 4                         WHERE SHE GOES
# 5                               Sprinter
# ..                                   ...
# 381         I'm Not Here To Make Friends
# 382                            TRUSTFALL
# 385            VIBE (feat. Jimin of BTS)
# 398                             Muï¿½ï¿½
# 404                      Sugar Rush Ride
#
#                              artist(s)_name  artist_count  released_year  \
# 0                          Latto, Jung Kook             2           2023
# 1                               Myke Towers             1           2023
# 2                            Olivia Rodrigo             1           2023
# 4                                 Bad Bunny             1           2023
# 5                         Dave, Central Cee             2           2023
# ...

# %%
a = spotify_data[spotify_data['artist(s)_name']=='The Weeknd']
a.head()
# Out:
#            track_name artist(s)_name  artist_count  released_year  \
# 47        Die For You     The Weeknd             1           2016
# 55    Blinding Lights     The Weeknd             1           2019
# 164   Save Your Tears     The Weeknd             1           2020
# 175          Reminder     The Weeknd             1           2016
# 292  Call Out My Name     The Weeknd             1           2018
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 47               11            24                  2483                 59
# 55               11            29                 43899                 69
# 164               3            20                 12688                 13
# 175              11            25                  6518                 17
# 292               3            29                 11087                  6
#
#         streams  in_apple_playlists  ...  bpm  key   mode danceability_%  \
# ...

# %%
a.plot.bar(x='track_name', y='in_spotify_playlists')
# Out:
# <Axes: xlabel='track_name'>

# %%
a.plot.bar(x='track_name', y='in_apple_playlists')
# Out:
# <Axes: xlabel='track_name'>

# %%
spotify_data['released_year'].unique()
# Out:
# array([2023, 2019, 2022, 2013, 2014, 2018, 2017, 2020, 2016, 2012, 1999,
#        2008, 1975, 2021, 2015, 2011, 2004, 1985, 2007, 2002, 2010, 1983,
#        1992, 1968, 1984, 2000, 1997, 1995, 2003, 1973, 1930, 1994, 1958,
#        1957, 1963, 1959, 1970, 1971, 1952, 1946, 1979, 1950, 1942, 1986,
#        2005, 1991, 1996, 1998, 1982, 1987])

# %%
spotify_data[spotify_data['released_year']==1987]
# Out:
#               track_name artist(s)_name  artist_count  released_year  \
# 871  Sweet Child O' Mine  Guns N' Roses             1           1987
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 871               1             1                 41231                  1
#
#         streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 871  1553497987                 228  ...  125  F#  Major             45
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 871         67       90              9                  11          10
#
#      speechiness_%
# 871              5
#
# [1 rows x 24 columns]
